# %% [markdown]
# <a href="https://colab.research.google.com/github/kingofgold2345-wq/ai/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import mediapipe as mp

mp_hand=mp.solutions.hands
mp_drawing=mp.solutions.drawing_utils
hands= mp_hand.Hands()

cap=cv2.VideoCapture(0)

while True:
    ret,frame=cap.read()

    if not ret:
        print("camera is not working")
        break


    frame=cv2.flip(frame,1)

    h,w,_=frame.shape


    frame_rgb=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)


    results=hands.process(frame_rgb)

    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:


            mp_drawing.draw_landmarks(frame,hand_landmarks,mp_hand.HAND_CONNECTIONS)

            for i,landmark in enumerate(hand_landmarks.landmark):
                cx=int(hand_landmarks.landmark[9].x*w)
                cy=int(hand_landmarks.landmark[9].y*h)


                cv2.circle(frame,(cx,cy),20,(255,0,0),-1)


cap.release()
cv2.destroyAllWindows()
# Out:
#   File "/tmp/ipykernel_170/1877595985.py", line 29
#     for hand_landmarks in results.multi  hand_landmarks:
#                                          ^
# SyntaxError: invalid syntax
